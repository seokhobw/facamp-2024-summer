# %% [markdown]
# *Copyright 2024 Jaeyoung Chun*
#
# You may not make copies of this and use or distribute it for any purpose.

# %% [markdown]
# # Aggregate EPL

# %%
import os
from statsbombpy import sb
import warnings
#ignore by message
warnings.filterwarnings("ignore", message="credentials were not supplied")

import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ## Competition

# %%
df_competitions = sb.competitions()

# %% [markdown]
# ## Extract EPL

# %%
df_epl = df_competitions[ df_competitions.competition_name == "Premier League" ]
df_epl
# Out:
#     competition_id  season_id country_name competition_name  \
# 63               2         27      England   Premier League
# 64               2         44      England   Premier League
#
#    competition_gender  competition_youth  competition_international  \
# 63               male              False                      False
# 64               male              False                      False
#
#    season_name               match_updated        match_updated_360  \
# 63   2015/2016  2024-01-25T11:45:53.333860  2021-06-13T16:17:31.694
# 64   2003/2004  2024-03-08T14:49:13.195793  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 63                None  2024-01-25T11:45:53.333860
# 64                None  2024-03-08T14:49:13.195793

# %%
for season_id in df_epl.season_id:
    print(season_id)
# Out:
# 27
# 44

# %% [markdown]
# ## Get Events

# %% [markdown]
# ### Combine

# %% [markdown]
# - Event Data를 다 모아서 하나의 DataFrame으로 만들기
# - 만들어진 DataFrame의 이름을 `df_all_events`로 설정

# %%
# ---------------------------
# Write your code here
# ---------------------------

# %% [markdown]
# ### Number of Events

# %% [markdown]
# `df_all_events` 에 저장된 이벤트의 갯수는 1,443,184 (약 140만개)

# %%
len(df_all_events)

# %% [markdown]
# ## Extract Only Shots

# %%
df_all_shots = df_all_events[ (df_all_events.type == "Shot") ]
df_all_shots
# Out:
#         ball_receipt_outcome ball_recovery_recovery_failure  \
# 3149                     NaN                            NaN
# 3150                     NaN                            NaN
# 3151                     NaN                            NaN
# 3152                     NaN                            NaN
# 3153                     NaN                            NaN
# ...                      ...                            ...
# 1443018                  NaN                            NaN
# 1443019                  NaN                            NaN
# 1443020                  NaN                            NaN
# 1443021                  NaN                            NaN
# 1443022                  NaN                            NaN
#
#         carry_end_location clearance_aerial_won clearance_body_part  \
# 3149                   NaN                  NaN                 NaN
# 3150                   NaN                  NaN                 NaN
# 3151                   NaN                  NaN                 NaN
# 3152                   NaN                  NaN                 NaN
# 3153                   NaN                  NaN                 NaN
# ...                    ...                  ...                 ...
# 1443018                NaN                  NaN                 NaN
# 1443019                NaN                  NaN                 NaN
# 1443020                NaN                  NaN                 NaN
# 1443021                NaN                  NaN                 NaN
# 1443022                NaN                  NaN                 NaN
#
#         clearance_head clearance_left_foot clearance_right_foot counterpress  \
# 3149               NaN                 NaN                  NaN          NaN
# 3150               NaN                 NaN                  NaN          NaN
# 3151               NaN                 NaN                  NaN          NaN
# 3152               NaN                 NaN                  NaN          NaN
# 3153               NaN                 NaN                  NaN          NaN
# ...                ...                 ...                  ...          ...
# 1443018            NaN                 NaN                  NaN          NaN
# 1443019            NaN                 NaN                  NaN          NaN
# 1443020            NaN                 NaN                  NaN          NaN
# 1443021            NaN                 NaN                  NaN          NaN
# 1443022            NaN                 NaN                  NaN          NaN
#
#         dribble_nutmeg  ... block_save_block shot_deflected  \
# 3149               NaN  ...              NaN            NaN
# 3150               NaN  ...              NaN            NaN
# 3151               NaN  ...              NaN            NaN
# 3152               NaN  ...              NaN            NaN
# 3153               NaN  ...              NaN            NaN
# ...                ...  ...              ...            ...
# 1443018            NaN  ...              NaN            NaN
# 1443019            NaN  ...              NaN            NaN
# 1443020            NaN  ...              NaN            NaN
# 1443021            NaN  ...              NaN            NaN
# 1443022            NaN  ...              NaN            NaN
#
#         player_off_permanent goalkeeper_success_in_play  shot_follows_dribble  \
# 3149                     NaN                        NaN                   NaN
# 3150                     NaN                        NaN                   NaN
# 3151                     NaN                        NaN                   NaN
# 3152                     NaN                        NaN                   NaN
# 3153                     NaN                        NaN                   NaN
# ...                      ...                        ...                   ...
# 1443018                  NaN                        NaN                   NaN
# 1443019                  NaN                        NaN                   NaN
# 1443020                  NaN                        NaN                   NaN
# 1443021                  NaN                        NaN                   NaN
# 1443022                  NaN                        NaN                   NaN
#
#         goalkeeper_lost_out half_start_late_video_start  \
# 3149                    NaN                         NaN
# 3150                    NaN                         NaN
# 3151                    NaN                         NaN
# 3152                    NaN                         NaN
# 3153                    NaN                         NaN
# ...                     ...                         ...
# 1443018                 NaN                         NaN
# 1443019                 NaN                         NaN
# 1443020                 NaN                         NaN
# 1443021                 NaN                         NaN
# 1443022                 NaN                         NaN
#
#         goalkeeper_lost_in_play goalkeeper_penalty_saved_to_post  \
# 3149                        NaN                              NaN
# 3150                        NaN                              NaN
# 3151                        NaN                              NaN
# 3152                        NaN                              NaN
# 3153                        NaN                              NaN
# ...                         ...                              ...
# 1443018                     NaN                              NaN
# 1443019                     NaN                              NaN
# 1443020                     NaN                              NaN
# 1443021                     NaN                              NaN
# 1443022                     NaN                              NaN
#
#         goalkeeper_saved_to_post
# 3149                         NaN
# 3150                         NaN
# 3151                         NaN
# 3152                         NaN
# 3153                         NaN
# ...                          ...
# 1443018                      NaN
# 1443019                      NaN
# 1443020                      NaN
# 1443021                      NaN
# 1443022                      NaN
#
# [10837 rows x 116 columns]

# %% [markdown]
# ## Write to File

# %%
path_data = "./data"

# %%
os.makedirs(path_data, exist_ok=True)

# %%
df_all_events.to_parquet(
    os.path.join(path_data, "data-epl-all.parquet")
)

# %%
df_all_shots.to_parquet(
    os.path.join(path_data, "data-epl-shots.parquet")
)
